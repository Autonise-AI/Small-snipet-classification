# %%
#****Autonise AI ******
#Naive Bayes Implementation
#All Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
import numpy as np
from scipy import stats

# %%
#Load the data

# %%
column1 = []
column2 = []
column3 = []

with open('data.txt', 'r') as f:
	for i in f:
		random, temp1, temp2, temp3 = i.split('\t')
		column1.append(temp1)
		column2.append(temp2)
		column3.append(temp3[:-1])


X_train, X_test, y_train, y_test = train_test_split(column1[1:], column2[1:], test_size=0.1, random_state=5)

# %%
bayes_clf = Pipeline([('vect', CountVectorizer()),
                      ('tfidf', TfidfTransformer()),
                      ('clf', MultinomialNB(alpha=0.01))
                      ])
bayes_clf.fit(X_train,y_train)
""" Predict the test dataset using Naive Bayes"""
predicted = bayes_clf.predict(X_test)
print('Naive Bayes correct prediction: {:4.4f}'.format(np.mean(predicted == y_test)))
# Out:
# Naive Bayes correct prediction: 0.3873

# %% [markdown]
# ## Result Analysis

# %%
correct = predicted[predicted== y_test]
X_test_ = X_test
# print(len(correct))
true_len = []
false_len = []
for i in range(len(X_test)):
    if y_test[i] == predicted[i]:
        print(X_test[i], ":",  predicted[i], "\n")
        true_len.append(len(X_test[i].split()))
    else:
        false_len.append(len(X_test[i].split()))
# Out:
# how to registered on myideaapp : Balance
#
# how to active offer in idea : mnp
#
# how to change ideatune : ideatune_change
#
# how to download vochers : idea_coverage
#
# how to increase speed limit : troubleshoot_check_FUP
#
# how to how to activate idea celebration pack : celebration
#
# how to enable ideaphone hotspot : myidea_hotspot_locator
#
# how to recharge other number : recharge
#
# how to you idea : bot_how_are_you
#
# how to get free 8gb data from idea : show_idea_plans_data_booster
#
# how to set idea tune on my number : ideatune_subscription
#
# how to logout of myidea account : myidea_forget_pass
#
# how to fallowing signal idea : Garbage
#
# how to get over your net plan : show_idea_plans_data_booster
#
# how to recharge idea card : myidea_raise_sr
#
# how to play kbc online : ideatv_record_fvrt
#
# how to upgrade sim prepaid to postpaid : ideamusic_radio_playlist
#
# how to transfer night : idea_sim_services_cashback_vouchers_are_non_transferable
#
# ...

# %%
true_len = np.array(true_len)
false_len = np.array(false_len)
print(np.mean(true_len))
print(np.mean(false_len))
# Out:
# 5.97175141243
# 6.32857142857

# %% [markdown]
# Naive Bayes correctly predicts the classification label for the input sentences that are generally short and starightforward. 39 percent accuracy is not that great.
